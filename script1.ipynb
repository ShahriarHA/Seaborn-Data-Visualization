# %% [markdown]
# # Day 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # Day 2 - scatter and line plots
# ### Goal: Explore relationships between two variables.

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=df.total_bill,y=df.tip,hue=df.sex,style=df.smoker)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x=df.total_bill,y=df.tip,hue=df.sex,style=df.smoker)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=df.total_bill,y=df.tip,hue=df.day,style=df.sex)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# # Day 3 - Distribution plots
# ### Goal: Visualize how data is distributed

# %%
df.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
sns.histplot(df.total_bill,bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(df.total_bill,kind='kde',)

# %%
sns.kdeplot(df.total_bill,fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Day 4 - Categorical plots (part 1)
# ### explore relationships between categories and numbers

# %%
sns.barplot(x=df.day,y=df.tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.countplot(df.day)
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.groupby('day').tip.count()
# Out:
# C:\Users\ShahriarHA\AppData\Local\Temp\ipykernel_9232\368115896.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('day').tip.count()
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: tip, dtype: int64

# %%
df.iloc[0]
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.loc[:,['day','tip']]
# Out:
#       day   tip
# 0     Sun  1.01
# 1     Sun  1.66
# 2     Sun  3.50
# 3     Sun  3.31
# 4     Sun  3.61
# ..    ...   ...
# 239   Sat  5.92
# 240   Sat  2.00
# 241   Sat  2.00
# 242   Sat  1.75
# 243  Thur  3.00
#
# [244 rows x 2 columns]

# %%
import numpy as np

# %%
sns.barplot(x=df.day,y=df.tip,estimator=np.median)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x=df.day,y=df.tip,estimator=np.max) # Each bar shows the maximum tip for each day.
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x=df.day,y=df.tip,ci=95)
# Out:
# C:\Users\ShahriarHA\AppData\Local\Temp\ipykernel_9232\2814426958.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x=df.day,y=df.tip,ci=95)
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x=df.day,y=df.tip,ci=None)
# Out:
# C:\Users\ShahriarHA\AppData\Local\Temp\ipykernel_9232\1182552398.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df.day,y=df.tip,ci=None)
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Day-5: Categorical plot (part 2)
# ### compare categories easily

# %%
sns.boxplot(x=df.day,y=df.total_bill,hue=df.sex)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x=df.day,y=df.tip,hue=df.sex,split=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x=df.day,y=df.tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
