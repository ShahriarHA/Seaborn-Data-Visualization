# %% [markdown]
# # Day 13 – Practice on a New Dataset
# ### Mini Project: Create a “Penguins Data Report” using 4–5 Seaborn plots.
# #### Load another dataset (penguins)
# #### Practice all major plot types with it.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("penguins")

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.loc[df.species == "Adelie"]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
df1.shape
# Out:
# (333, 7)

# %%
df1.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df1.species.value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.barplot(x=df1.species,y=df1.bill_depth_mm,estimator=np.min)
# Out:
# <Axes: xlabel='species', ylabel='bill_depth_mm'>

# %%
df1.island.value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
df1.loc[(df1.species=="Adelie") & (df1.sex == "Male"),["bill_depth_mm","sex"]]
# Out:
#      bill_depth_mm   sex
# 0             18.7  Male
# 5             20.6  Male
# 7             19.6  Male
# 13            21.2  Male
# 14            21.1  Male
# ..             ...   ...
# 143           17.0  Male
# 145           18.7  Male
# 146           18.6  Male
# 149           18.1  Male
# 151           18.5  Male
#
# [73 rows x 2 columns]

# %%
sns.countplot(x=df.species,hue=df.sex)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
df1.groupby("species").bill_depth_mm.min()
# Out:
# species
# Adelie       15.5
# Chinstrap    16.4
# Gentoo       13.1
# Name: bill_depth_mm, dtype: float64

# %%
df1.groupby(['species',"sex"]).sex.count()
# Out:
# species    sex
# Adelie     Female    73
#            Male      73
# Chinstrap  Female    34
#            Male      34
# Gentoo     Female    58
#            Male      61
# Name: sex, dtype: int64

# %%
sns.boxplot(x = df1.species,y=df1.bill_depth_mm)
# Out:
# <Axes: xlabel='species', ylabel='bill_depth_mm'>

# %%
df1.groupby(["species"]).bill_depth_mm.mean()
# Out:
# species
# Adelie       18.347260
# Chinstrap    18.420588
# Gentoo       14.996639
# Name: bill_depth_mm, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 28.9+ KB

# %%
sns.pairplot(df1)

# %%
a = sns.FacetGrid(data=df1,col="island",row="sex")
a.map(sns.barplot,"species","body_mass_g").add_legend()
plt.show()
# Out:
# C:\Users\ShahriarHA\AppData\Roaming\Python\Python314\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df1.groupby(["species","sex"]).body_mass_g.count()
# Out:
# species    sex
# Adelie     Female    73
#            Male      73
# Chinstrap  Female    34
#            Male      34
# Gentoo     Female    58
#            Male      61
# Name: body_mass_g, dtype: int64
